# %%
import sys
import time
import importlib
from collections import deque
from IPython.display import Image

sys.path.append("..")
import utility as U

# %%
pcode = "p21b"
pmod = importlib.import_module(pcode)

# %%
pmachine = pmod.PMachine()
#pmachine.test_code = 'A'

# %%
imgpath = U.create_diagram(pmachine, pcode, keepgv=True)
Image(imgpath)
# Out:
# Writing to path: /userdata/external/AdventFlow/diagram/p21b.gv
# Wrote GV output to path /userdata/external/AdventFlow/diagram/p21b.gv
# dot /userdata/external/AdventFlow/diagram/p21b.gv -Tpng > /userdata/external/AdventFlow/diagram/p21b.png

# %%
#pmod.run_tests()

# %%
pmachine.run2_completion()
#pmachine.run2_step_count(100)
# Out:
# Got IP binding = 1 and 31 lines of instructions
# Have 10 simulator checks
# Have 20 simulator checks
# Have 30 simulator checks
# Have 40 simulator checks
# Have 50 simulator checks
# Have 60 simulator checks
# Have 70 simulator checks
# Have 80 simulator checks
# Have 90 simulator checks
# Have 100 simulator checks
# Have 110 simulator checks
# Have 120 simulator checks
# Have 130 simulator checks
# Have 140 simulator checks
# Have 150 simulator checks
# Have 160 simulator checks
# Have 170 simulator checks
# Have 180 simulator checks
# Have 190 simulator checks
# Have 200 simulator checks

# %%
pmachine.get_result()
# Out:
# Found cycle after 95499 yields
# Last observed r4 is 103548
# Last observed r4 is 4054948
# Last observed r4 is 8744419
# Last observed r4 is 13555206
# Last observed r4 is 8399150
# Last observed r4 is 16404615
# Last observed r4 is 917647
# Last observed r4 is 13023923
# Last observed r4 is 2143665
# Last observed r4 is 3671052
# Last observed r4 is 13910700
# Last observed r4 is 13335694
# Last observed r4 is 2112144
# Last observed r4 is 13520502
# Last observed r4 is 14621494
# Last observed r4 is 11506251
# Last observed r4 is 5154057
# Last observed r4 is 11895614
# Last observed r4 is 7165053
# Last observed r4 is 11445979
# Last observed r4 is 15387181
# Last observed r4 is 3784923
# Last observed r4 is 6580645
# Last observed r4 is 2179496
# Last observed r4 is 2820429
# Last observed r4 is 3812738
# Last observed r4 is 11289445
# Last observed r4 is 2239370
# Last observed r4 is 720515
# Last observed r4 is 14357681
# Last observed r4 is 1660273
# Last observed r4 is 16244372
# Last observed r4 is 1748408
# Last observed r4 is 9694215
# Last observed r4 is 14216275
# Last observed r4 is 9484345
# Last observed r4 is 15295519
# Last observed r4 is 14851013
# Last observed r4 is 7079636
# Last observed r4 is 8696498
# Last observed r4 is 1664512
# Last observed r4 is 2804794
# Last observed r4 is 6809156
# Last observed r4 is 12918112
# Last observed r4 is 1153149
# Last observed r4 is 11722123
# Last observed r4 is 13798312
# Last observed r4 is 5164845
# Last observed r4 is 13955396
# Last observed r4 is 8116045
# Last observed r4 is 6082512
# Last observed r4 is 16469495
# Last observed r4 is 10902708
# Last observed r4 is 11822262
# Last observed r4 is 9193214
# Last observed r4 is 7451632
# Last observed r4 is 698487
# Last observed r4 is 1037991
# Last observed r4 is 13478177
# Last observed r4 is 583828
# Last observed r4 is 10188664
# Last observed r4 is 5044673
# Last observed r4 is 1228996
# Last observed r4 is 13527118
# Last observed r4 is 849160
# Last observed r4 is 15672101
# Last observed r4 is 2956608
# Last observed r4 is 14497429
# Last observed r4 is 4430789
# Last observed r4 is 13313012
# Last observed r4 is 16191825
# Last observed r4 is 14341594
# Last observed r4 is 12233781
# Last observed r4 is 14683573
# Last observed r4 is 4897840
# Last observed r4 is 14109910
# Last observed r4 is 639036
# Last observed r4 is 3100168
# Last observed r4 is 2591916
# Last observed r4 is 9260878
# Last observed r4 is 11686753
# Last observed r4 is 9760336
# Last observed r4 is 15583302
# Last observed r4 is 344666
# Last observed r4 is 7062280
# Last observed r4 is 1908813
# Last observed r4 is 9721927
# Last observed r4 is 3174645
# Last observed r4 is 5891307
# Last observed r4 is 3325497
# Last observed r4 is 10153771
# Last observed r4 is 1571714
# Last observed r4 is 5914935
# Last observed r4 is 4201192
# Last observed r4 is 10084670
# Last observed r4 is 10628279
# Last observed r4 is 4092243
# Last observed r4 is 2920184
# Last observed r4 is 11847142
# Last observed r4 is 5152423
# Last observed r4 is 13462377
# Last observed r4 is 1455902
# Last observed r4 is 1186599
# Last observed r4 is 10061866
# Last observed r4 is 2622442
# Last observed r4 is 2308413
# Last observed r4 is 6610858
# Last observed r4 is 13291661
# Last observed r4 is 16532209
# Last observed r4 is 4396965
# Last observed r4 is 13513264
# Last observed r4 is 15372360
# Last observed r4 is 13393842
# Last observed r4 is 5827101
# Last observed r4 is 5866437
# Last observed r4 is 10551758
# Last observed r4 is 6538463
# Last observed r4 is 139619
# Last observed r4 is 12395844
# Last observed r4 is 4295129
# Last observed r4 is 16393880
# Last observed r4 is 15740856
# Last observed r4 is 1688683
# Last observed r4 is 8643289
# Last observed r4 is 5600895
# Last observed r4 is 5282315
# Last observed r4 is 7938247
# Last observed r4 is 4315721
# Last observed r4 is 9901169
# Last observed r4 is 10346565
# Last observed r4 is 15742447
# Last observed r4 is 3484310
# Last observed r4 is 8350004
# Last observed r4 is 1451491
# Last observed r4 is 10450436
# Last observed r4 is 4531992
# Last observed r4 is 10684127
# Last observed r4 is 15759061
# Last observed r4 is 9403169
# Last observed r4 is 16388972
# Last observed r4 is 1187257
# Last observed r4 is 996594
# Last observed r4 is 8944736
# Last observed r4 is 16664080
# Last observed r4 is 6258796
# Last observed r4 is 7235914
# Last observed r4 is 7405141
# Last observed r4 is 6426217
# Last observed r4 is 3318683
# Last observed r4 is 11468142
# Last observed r4 is 4319157
# Last observed r4 is 10234586
# Last observed r4 is 3310264
# Last observed r4 is 6527228
# Last observed r4 is 7249662
# Last observed r4 is 9730302
# Last observed r4 is 11159402
# Last observed r4 is 9994551
# Last observed r4 is 8331538
# Last observed r4 is 11542229
# Last observed r4 is 929993
# Last observed r4 is 6367281
# Last observed r4 is 1095015
# Last observed r4 is 12598622
# Last observed r4 is 274763
# Last observed r4 is 13282274
# Last observed r4 is 6358467
# Last observed r4 is 5111154
# Last observed r4 is 15912459
# Last observed r4 is 16552977
# Last observed r4 is 3354183
# Last observed r4 is 6124453
# Last observed r4 is 8999306
# Last observed r4 is 8517275
# Last observed r4 is 413187
# Last observed r4 is 15140437
# Last observed r4 is 9835139
# Last observed r4 is 4544681
# Last observed r4 is 12343115
# Last observed r4 is 9705536
# Last observed r4 is 900208
# Last observed r4 is 13633964
# Last observed r4 is 11459505
# Last observed r4 is 14103772
# Last observed r4 is 15116502
# Last observed r4 is 12243304
# Last observed r4 is 1070843
# Last observed r4 is 6724275
# Last observed r4 is 12572273
# Last observed r4 is 7874863
# Last observed r4 is 16195970
# Last observed r4 is 4795725
# Last observed r4 is 12106256
# Last observed r4 is 16406782
# Last observed r4 is 1081580
# Last observed r4 is 9315376
# Last observed r4 is 14290794
# Last observed r4 is 8924367
# Last observed r4 is 10023997
# Last observed r4 is 10847263
# Last observed r4 is 10392185
# Last observed r4 is 1975619
# Last observed r4 is 10341756
# Last observed r4 is 15947785
# Last observed r4 is 6396453
# Last observed r4 is 497637
# Last observed r4 is 13258332
# Last observed r4 is 6075676
# Last observed r4 is 10493137
# Last observed r4 is 3842907
# Last observed r4 is 8385542
# Last observed r4 is 8391020
# Last observed r4 is 2577793
# Last observed r4 is 5486494
# Last observed r4 is 12449339
# Last observed r4 is 7341047
# Last observed r4 is 11194252
# Last observed r4 is 16725637
# Last observed r4 is 1574603
# Last observed r4 is 294059
# Last observed r4 is 15079221
# Last observed r4 is 5420652
# Last observed r4 is 15919948
# Last observed r4 is 11588633
# Last observed r4 is 938843
# Last observed r4 is 13818834
# Last observed r4 is 10210971
# Last observed r4 is 6292985
# Last observed r4 is 5535476
# Last observed r4 is 8997882
# Last observed r4 is 9587349
# Last observed r4 is 14248267
# Last observed r4 is 14708982
# Last observed r4 is 1030862
# Last observed r4 is 15396234
# Last observed r4 is 8792653
# Last observed r4 is 7277007
# Last observed r4 is 16150548
# Last observed r4 is 14375098
# Last observed r4 is 10866048
# Last observed r4 is 971949
# Last observed r4 is 3853729
# Last observed r4 is 4498706
# Last observed r4 is 14103547
# Last observed r4 is 10834986
# Last observed r4 is 5474138
# Last observed r4 is 15920511
# Last observed r4 is 5815828
# Last observed r4 is 871694
# Last observed r4 is 4883375
# Last observed r4 is 2621138
# Last observed r4 is 7813634
# Last observed r4 is 7508574
# Last observed r4 is 7252510
# Last observed r4 is 7590154
# Last observed r4 is 16714345
# Last observed r4 is 7304683
# Last observed r4 is 10465076
# Last observed r4 is 4657625
# Last observed r4 is 12511330
# Last observed r4 is 6254932
# Last observed r4 is 5347499
# Last observed r4 is 13815605
# Last observed r4 is 8425224
# Last observed r4 is 5419499
# Last observed r4 is 2370268
# Last observed r4 is 12816694
# Last observed r4 is 2403293
# Last observed r4 is 10603714
# Last observed r4 is 7575982
# Last observed r4 is 14391069
# Last observed r4 is 13851168
# Last observed r4 is 6372780
# Last observed r4 is 2017909
# Last observed r4 is 13276911
# Last observed r4 is 15203533
# Last observed r4 is 7337777
# Last observed r4 is 13171928
# Last observed r4 is 8864824
# Last observed r4 is 16334282
# Last observed r4 is 4813751
# Last observed r4 is 13415172
# Last observed r4 is 15470183
# Last observed r4 is 11775651
# Last observed r4 is 10400633
# Last observed r4 is 16154396
# Last observed r4 is 11166761
# Last observed r4 is 13950745
# Last observed r4 is 8037466
# Last observed r4 is 9663788
# Last observed r4 is 2326611
# Last observed r4 is 12095515
# Last observed r4 is 12541493
# Last observed r4 is 1261315
# Last observed r4 is 4910722
# Last observed r4 is 9856910
# Last observed r4 is 3389351
# Last observed r4 is 13207494
# Last observed r4 is 7768021
# Last observed r4 is 7142508
# Last observed r4 is 1953472
# Last observed r4 is 9775950
# Last observed r4 is 5897397
# Last observed r4 is 7112207
# Last observed r4 is 13140819
# Last observed r4 is 15172520
# Last observed r4 is 10671553
# Last observed r4 is 579762
# Last observed r4 is 11345314
# Last observed r4 is 3818459
# Last observed r4 is 15538214
# Last observed r4 is 15194314
# Last observed r4 is 65588
# Last observed r4 is 16667992
# Last observed r4 is 6660251
# Last observed r4 is 5848105
# Last observed r4 is 12713451
# Last observed r4 is 11769282
# Last observed r4 is 1908085
# Last observed r4 is 13548820
# Last observed r4 is 11268519
# Last observed r4 is 3330008
# Last observed r4 is 16250113
# Last observed r4 is 12085422
# Last observed r4 is 13202678
# Last observed r4 is 5743530
# Last observed r4 is 1841495
# Last observed r4 is 14475382
# Last observed r4 is 2014354
# Last observed r4 is 8873528
# Last observed r4 is 11115100
# Last observed r4 is 5985234
# Last observed r4 is 6402603
# Last observed r4 is 6619951
# Last observed r4 is 13802928
# Last observed r4 is 10871495
# Last observed r4 is 2107615
# Last observed r4 is 1973009
# Last observed r4 is 3844620
# Last observed r4 is 15206776
# Last observed r4 is 13253853
# Last observed r4 is 10455533
# Last observed r4 is 12182110
# Last observed r4 is 3532592
# Last observed r4 is 631479
# Last observed r4 is 3463227
# Last observed r4 is 9892209
# Last observed r4 is 1587706
# Last observed r4 is 15825603
# Last observed r4 is 9963567
# Last observed r4 is 4125961
# Last observed r4 is 2508382
# Last observed r4 is 94062
# Last observed r4 is 12676701
# Last observed r4 is 5757537
# Last observed r4 is 2218859
# Last observed r4 is 16002256
# Last observed r4 is 682420
# Last observed r4 is 1026791
# Last observed r4 is 14960149
# Last observed r4 is 6138157
# Last observed r4 is 13802920
# Last observed r4 is 8323119
# Last observed r4 is 6601315
# Last observed r4 is 3756235
# Last observed r4 is 9794437
# Last observed r4 is 2496146
# Last observed r4 is 8236442
# Last observed r4 is 6595907
# Last observed r4 is 15043902
# Last observed r4 is 897991
# Last observed r4 is 14602592
# Last observed r4 is 894831
# Last observed r4 is 1242156
# Last observed r4 is 13378714
# Last observed r4 is 1810866
# Last observed r4 is 5677417
# Last observed r4 is 3154642
# Last observed r4 is 14610740
# Last observed r4 is 3678283
# Last observed r4 is 10930005
# Last observed r4 is 3130684
# Last observed r4 is 9277831
# Last observed r4 is 7869838
# Last observed r4 is 14986715
# Last observed r4 is 600526
# Last observed r4 is 9132607
# Last observed r4 is 11503009
# Last observed r4 is 16287110
# Last observed r4 is 12562867
# Last observed r4 is 8425944
# Last observed r4 is 16104141
# Last observed r4 is 13457241
# Last observed r4 is 15219578
# Last observed r4 is 294309
# Last observed r4 is 10547196
# Last observed r4 is 1434567
# Last observed r4 is 6774632
# Last observed r4 is 9087357
# Last observed r4 is 8763602
# Last observed r4 is 12910774
# Last observed r4 is 3886442
# Last observed r4 is 3666621
# Last observed r4 is 73015
# Last observed r4 is 8730950
# Last observed r4 is 15935883
# Last observed r4 is 3210324
# Last observed r4 is 7131620
# Last observed r4 is 1876117
# Last observed r4 is 15969311
# Last observed r4 is 11365883
# Last observed r4 is 7059078
# Last observed r4 is 9006530
# Last observed r4 is 3306751
# Last observed r4 is 15502819
# Last observed r4 is 3653790
# Last observed r4 is 3794696
# Last observed r4 is 4930411
# Last observed r4 is 1881278
# Last observed r4 is 10169310
# Last observed r4 is 1831911
# Last observed r4 is 8986074
# Last observed r4 is 2507511
# Last observed r4 is 8983077
# Last observed r4 is 7233109
# Last observed r4 is 6182899
# Last observed r4 is 6695278
# Last observed r4 is 1523817
# Last observed r4 is 1490937
# Last observed r4 is 16517232
# Last observed r4 is 14644200
# Last observed r4 is 5354393
# Last observed r4 is 4430562
# Last observed r4 is 8394402
# Last observed r4 is 2486888
# Last observed r4 is 5364770
# Last observed r4 is 10067950
# Last observed r4 is 4780565
# Last observed r4 is 14852165
# Last observed r4 is 3533553
# Last observed r4 is 3917173
# Last observed r4 is 11448582
# Last observed r4 is 2594577
# Last observed r4 is 14944000
# Last observed r4 is 13560535
# Last observed r4 is 5783397
# Last observed r4 is 7186826
# Last observed r4 is 10927743
# Last observed r4 is 6541913
# Last observed r4 is 4649999
# Last observed r4 is 7567599
# Last observed r4 is 4140631
# Last observed r4 is 12011993
# Last observed r4 is 7348138
# Last observed r4 is 13948625
# Last observed r4 is 6350721
# Last observed r4 is 12556126
# Last observed r4 is 15934335
# Last observed r4 is 15112218
# Last observed r4 is 11065572
# Last observed r4 is 4262072
# Last observed r4 is 8413356
# Last observed r4 is 13063968
# Last observed r4 is 13444221
# Last observed r4 is 9350219
# Last observed r4 is 2014835
# Last observed r4 is 10534301
# Last observed r4 is 1546456
# Last observed r4 is 7550862
# Last observed r4 is 9372139
# Last observed r4 is 14590144
# Last observed r4 is 8896806
# Last observed r4 is 1774665
# Last observed r4 is 6210425
# Last observed r4 is 3559404
# Last observed r4 is 6018217
# Last observed r4 is 7587865
# Last observed r4 is 11524805
# Last observed r4 is 6318239
# Last observed r4 is 2625361
# Last observed r4 is 6007886
# Last observed r4 is 16320944
# Last observed r4 is 15369653
# Last observed r4 is 9834774
# Last observed r4 is 5998233
# Last observed r4 is 5582475
# Last observed r4 is 13248999
# Last observed r4 is 13103472
# Last observed r4 is 4432311
# Last observed r4 is 9906112
# Last observed r4 is 2494877
# Last observed r4 is 8066958
# Last observed r4 is 9877027
# Last observed r4 is 13924365
# Last observed r4 is 5715975
# Last observed r4 is 12234027
# Last observed r4 is 8877360
# Last observed r4 is 2810011
# Last observed r4 is 2070571
# Last observed r4 is 3301071
# Last observed r4 is 7537261
# Last observed r4 is 3541739
# Last observed r4 is 1981561
# Last observed r4 is 820637
# Last observed r4 is 4337284
# Last observed r4 is 9832988
# Last observed r4 is 9477500
# Last observed r4 is 6734933
# Last observed r4 is 6775377
# Last observed r4 is 10675763
# Last observed r4 is 11456753
# Last observed r4 is 12987305
# Last observed r4 is 4625692
# Last observed r4 is 9021055
# Last observed r4 is 353911
# Last observed r4 is 5839475
# Last observed r4 is 7950679
# Last observed r4 is 7994210
# Last observed r4 is 2179533
# Last observed r4 is 14606668
# Last observed r4 is 2923651
# Last observed r4 is 4995605
# Last observed r4 is 10793209
# Last observed r4 is 14854387
# Last observed r4 is 4440355
# Last observed r4 is 13115108
# Last observed r4 is 7289774
# Last observed r4 is 8819075
# Last observed r4 is 6200256
# Last observed r4 is 13565449
# Last observed r4 is 5188367
# Last observed r4 is 14770438
# Last observed r4 is 14222375
# Last observed r4 is 16278093
# Last observed r4 is 2245613
# Last observed r4 is 2913268
# Last observed r4 is 14224151
# Last observed r4 is 9613356
# Last observed r4 is 15474934
# Last observed r4 is 10154498
# Last observed r4 is 14203490
# Last observed r4 is 11081972
# Last observed r4 is 9225000
# Last observed r4 is 14342883
# Last observed r4 is 1996989
# Last observed r4 is 16232197
# Last observed r4 is 12262244
# Last observed r4 is 7009833
# Last observed r4 is 12980699
# Last observed r4 is 4806280
# Last observed r4 is 7336146
# Last observed r4 is 15694332
# Last observed r4 is 13832475
# Last observed r4 is 11544908
# Last observed r4 is 12346961
# Last observed r4 is 5860105
# Last observed r4 is 13562754
# Last observed r4 is 5451863
# Last observed r4 is 8088487
# Last observed r4 is 15802098
# Last observed r4 is 14385392
# Last observed r4 is 7123946
# Last observed r4 is 15300825
# Last observed r4 is 4908679
# Last observed r4 is 15638373
# Last observed r4 is 361372
# Last observed r4 is 8733031
# Last observed r4 is 5481990
# Last observed r4 is 8582826
# Last observed r4 is 5323190
# Last observed r4 is 14631967
# Last observed r4 is 14169719
# Last observed r4 is 11387999
# Last observed r4 is 14573777
# Last observed r4 is 14267497
# Last observed r4 is 12259043
# Last observed r4 is 14426097
# Last observed r4 is 10128122
# Last observed r4 is 13438882
# Last observed r4 is 9063197
# Last observed r4 is 6429124
# Last observed r4 is 3478287
# Last observed r4 is 8846032
# Last observed r4 is 7208600
# Last observed r4 is 10728054
# Last observed r4 is 1305878
# Last observed r4 is 7938665
# Last observed r4 is 2685249
# Last observed r4 is 8414264
# Last observed r4 is 15961192
# Last observed r4 is 1043078
# Last observed r4 is 882914
# Last observed r4 is 10055038
# Last observed r4 is 16254371
# Last observed r4 is 4934298
# Last observed r4 is 11096274
# Last observed r4 is 2627738
# Last observed r4 is 5675130
# Last observed r4 is 15379412
# Last observed r4 is 4007577
# Last observed r4 is 3538593
# Last observed r4 is 9904633
# Last observed r4 is 2822082
# Last observed r4 is 8581063
# Last observed r4 is 16129038
# Last observed r4 is 14502420
# Last observed r4 is 11586662
# Last observed r4 is 12878474
# Last observed r4 is 1495320
# Last observed r4 is 15111295
# Last observed r4 is 3390143
# Last observed r4 is 12990393
# Last observed r4 is 11827960
# Last observed r4 is 6115402
# Last observed r4 is 4628670
# Last observed r4 is 15020280
# Last observed r4 is 1886944
# Last observed r4 is 13675210
# Last observed r4 is 1729476
# Last observed r4 is 6125169
# Last observed r4 is 1349849
# Last observed r4 is 7737611
# Last observed r4 is 385448
# Last observed r4 is 1086777
# Last observed r4 is 14700372
# Last observed r4 is 2356335
# Last observed r4 is 2221315
# Last observed r4 is 6997586
# Last observed r4 is 841846
# Last observed r4 is 9273306
# Last observed r4 is 14373749
# Last observed r4 is 1990020
# Last observed r4 is 1726215
# Last observed r4 is 10923134
# Last observed r4 is 3065092
# Last observed r4 is 8216415
# Last observed r4 is 7670212
# Last observed r4 is 13041925
# Last observed r4 is 12123542
# Last observed r4 is 942811
# Last observed r4 is 15281705
# Last observed r4 is 8561661
# Last observed r4 is 14403236
# Last observed r4 is 788956
# Last observed r4 is 13833557
# Last observed r4 is 2760446
# Last observed r4 is 5159954
# Last observed r4 is 4817096
# Last observed r4 is 1538028
# Last observed r4 is 16520241
# Last observed r4 is 13458471
# Last observed r4 is 2965729
# Last observed r4 is 7611923
# Last observed r4 is 14875287
# Last observed r4 is 11891345
# Last observed r4 is 11048221
# Last observed r4 is 15797704
# Last observed r4 is 12004617
# Last observed r4 is 14471166
# Last observed r4 is 6003297
# Last observed r4 is 2437847
# Last observed r4 is 7035231
# Last observed r4 is 5431272
# Last observed r4 is 15078177
# Last observed r4 is 9532684
# Last observed r4 is 8778525
# Last observed r4 is 1956522
# Last observed r4 is 4873432
# Last observed r4 is 450030
# Last observed r4 is 445405
# Last observed r4 is 8649048
# Last observed r4 is 4894539
# Last observed r4 is 6448690
# Last observed r4 is 6831454
# Last observed r4 is 11252867
# Last observed r4 is 732695
# Last observed r4 is 4975453
# Last observed r4 is 5932900
# Last observed r4 is 2855957
# Last observed r4 is 7566797
# Last observed r4 is 1172262
# Last observed r4 is 5556617
# Last observed r4 is 9049924
# Last observed r4 is 4136149
# Last observed r4 is 15436209
# Last observed r4 is 14854830
# Last observed r4 is 10773558
# Last observed r4 is 919246
# Last observed r4 is 590710
# Last observed r4 is 13579841
# Last observed r4 is 10304687
# Last observed r4 is 9548233
# Last observed r4 is 12402624
# Last observed r4 is 9210071
# Last observed r4 is 6608637
# Last observed r4 is 12986101
# Last observed r4 is 8384547
# Last observed r4 is 11334639
# Last observed r4 is 4378488
# Last observed r4 is 3501201
# Last observed r4 is 1560391
# Last observed r4 is 1770058
# Last observed r4 is 3370698
# Last observed r4 is 14344286
# Last observed r4 is 11014644
# Last observed r4 is 10792985
# Last observed r4 is 10608723
# Last observed r4 is 3688485
# Last observed r4 is 11436011
# Last observed r4 is 5252398
# Last observed r4 is 6947219
# Last observed r4 is 962860
# Last observed r4 is 4155523
# Last observed r4 is 8242695
# Last observed r4 is 11691435
# Last observed r4 is 2936656
# Last observed r4 is 6086759
# Last observed r4 is 5578293
# Last observed r4 is 11008629
# Last observed r4 is 13884023
# Last observed r4 is 621153
# Last observed r4 is 13789041
# Last observed r4 is 14882644
# Last observed r4 is 15032013
# Last observed r4 is 1852973
# Last observed r4 is 603485
# Last observed r4 is 8796744
# Last observed r4 is 14084032
# Last observed r4 is 6846237
# Last observed r4 is 6316378
# Last observed r4 is 15768035
# Last observed r4 is 6022902
# Last observed r4 is 1719826
# Last observed r4 is 12836862
# Last observed r4 is 12689683
# Last observed r4 is 16299326
# Last observed r4 is 14826763
# Last observed r4 is 9630360
# Last observed r4 is 11126700
# Last observed r4 is 14198855
# Last observed r4 is 16100145
# Last observed r4 is 3075054
# Last observed r4 is 16722611
# Last observed r4 is 14122249
# Last observed r4 is 8247086
# Last observed r4 is 13116569
# Last observed r4 is 1228723
# Last observed r4 is 10732562
# Last observed r4 is 6163884
# Last observed r4 is 10241263
# Last observed r4 is 8969297
# Last observed r4 is 11952787
# Last observed r4 is 3417353
# Last observed r4 is 10093024
# Last observed r4 is 11876915
# Last observed r4 is 10425899
# Last observed r4 is 111197
# Last observed r4 is 16220997
# Last observed r4 is 13744216
# Last observed r4 is 12610796
# Last observed r4 is 6219596
# Last observed r4 is 12318553
# Last observed r4 is 14144916
# Last observed r4 is 6449111
# Last observed r4 is 6439318
# Last observed r4 is 1435917
# Last observed r4 is 15686512
# Last observed r4 is 14303753
# Last observed r4 is 12139575
# Last observed r4 is 6722197
# Last observed r4 is 7204591
# Last observed r4 is 13264667
# Last observed r4 is 3737626
# Last observed r4 is 7887386
# Last observed r4 is 15307804
# Last observed r4 is 5540220
# Last observed r4 is 4864205
# Last observed r4 is 7406681
# Last observed r4 is 8574731
# Last observed r4 is 2362818
# Last observed r4 is 13427155
# Last observed r4 is 11186882
# Last observed r4 is 9265426
# Last observed r4 is 12509423
# Last observed r4 is 5027139
# Last observed r4 is 5084870
# Last observed r4 is 10617048
# Last observed r4 is 12476474
# Last observed r4 is 14389780
# Last observed r4 is 7310744
# Last observed r4 is 5013923
# Last observed r4 is 4171858
# Last observed r4 is 9455716
# Last observed r4 is 3749152
# Last observed r4 is 9305745
# Last observed r4 is 10606993
# Last observed r4 is 8229168
# Last observed r4 is 12656297
# Last observed r4 is 4745525
# Last observed r4 is 14988708
# Last observed r4 is 12446145
# Last observed r4 is 209924
# Last observed r4 is 16225842
# Last observed r4 is 8229354
# Last observed r4 is 4797175
# Last observed r4 is 2823883
# Last observed r4 is 9880001
# Last observed r4 is 1872186
# Last observed r4 is 9515463
# Last observed r4 is 11676314
# Last observed r4 is 1150250
# Last observed r4 is 14110895
# Last observed r4 is 11287163
# Last observed r4 is 16056875
# Last observed r4 is 7861723
# Last observed r4 is 5984732
# Last observed r4 is 14829559
# Last observed r4 is 8268374
# Last observed r4 is 9616738
# Last observed r4 is 15384029
# Last observed r4 is 10032774
# Last observed r4 is 11926364
# Last observed r4 is 4222191
# Last observed r4 is 15517381
# Last observed r4 is 12487189
# Last observed r4 is 9972847
# Last observed r4 is 14052301
# Last observed r4 is 415160
# Last observed r4 is 4120595
# Last observed r4 is 10397807
# Last observed r4 is 8242667
# Last observed r4 is 3054814
# Last observed r4 is 560748
# Last observed r4 is 15209846
# Last observed r4 is 14722275
# Last observed r4 is 9694777
# Last observed r4 is 8124923
# Last observed r4 is 5958860
# Last observed r4 is 6170826
# Last observed r4 is 16146476
# Last observed r4 is 13620466
# Last observed r4 is 4931648
# Last observed r4 is 8634474
# Last observed r4 is 9015792
# Last observed r4 is 7499245
# Last observed r4 is 15554494
# Last observed r4 is 15947161
# Last observed r4 is 9797802
# Last observed r4 is 13767158
# Last observed r4 is 14197837
# Last observed r4 is 11717183
# Last observed r4 is 5828425
# Last observed r4 is 6778790
# Last observed r4 is 3682599
# Last observed r4 is 5241330
# Last observed r4 is 192381
# Last observed r4 is 898704
# Last observed r4 is 5997494
# Last observed r4 is 5905351
# Last observed r4 is 15442466
# Last observed r4 is 4447330
# Last observed r4 is 12755156
# Last observed r4 is 13422574
# Last observed r4 is 16629377
# Last observed r4 is 12846321
# Last observed r4 is 12197743
# Last observed r4 is 30878
# Last observed r4 is 4380270
# Last observed r4 is 15524962
# Last observed r4 is 2992042
# Last observed r4 is 5367981
# Last observed r4 is 6119851
# Last observed r4 is 7752314
# Last observed r4 is 3802326
# Last observed r4 is 11280128
# Last observed r4 is 14081223
# Last observed r4 is 4349807
# Last observed r4 is 8944822
# Last observed r4 is 10504690
# Last observed r4 is 13862035
# Last observed r4 is 43343
# Last observed r4 is 1793594
# Last observed r4 is 8823830
# Last observed r4 is 5570596
# Last observed r4 is 329540
# Last observed r4 is 3683139
# Last observed r4 is 8919160
# Last observed r4 is 1170836
# Last observed r4 is 5989597
# Last observed r4 is 15685637
# Last observed r4 is 4858669
# Last observed r4 is 11474764
# Last observed r4 is 9056889
# Last observed r4 is 590727
# Last observed r4 is 2217924
# Last observed r4 is 4504263
# Last observed r4 is 16724951
# Last observed r4 is 2003254
# Last observed r4 is 8373073
# Last observed r4 is 9703508
# Last observed r4 is 11459876
# Last observed r4 is 14278807
# Last observed r4 is 12262809
# Last observed r4 is 1874122
# Last observed r4 is 3486598
# Last observed r4 is 13220997
# Last observed r4 is 15935247
# Last observed r4 is 2506414
# Last observed r4 is 12989334
# Last observed r4 is 11161787
# Last observed r4 is 12210171
# Last observed r4 is 2717874
# Last observed r4 is 13387170
# Last observed r4 is 1760803
# Last observed r4 is 1586465
# Last observed r4 is 7515524
# Last observed r4 is 15706099
# Last observed r4 is 7851886
# Last observed r4 is 3742479
# Last observed r4 is 4920900
# Last observed r4 is 2539356
# Last observed r4 is 1114169
# Last observed r4 is 2537895
# Last observed r4 is 7175220
# Last observed r4 is 802840
# Last observed r4 is 8584072
# Last observed r4 is 14943309
# Last observed r4 is 12396451
# Last observed r4 is 12538392
# Last observed r4 is 6695152
# Last observed r4 is 12001238
# Last observed r4 is 15800407
# Last observed r4 is 14289497
# Last observed r4 is 16612783
# Last observed r4 is 13298402
# Last observed r4 is 9023818
# Last observed r4 is 4974395
# Last observed r4 is 5585274
# Last observed r4 is 12559959
# Last observed r4 is 7947793
# Last observed r4 is 14524093
# Last observed r4 is 13050853
# Last observed r4 is 11150024
# Last observed r4 is 2687732
# Last observed r4 is 8114626
# Last observed r4 is 8745321
# Last observed r4 is 14541148
# Last observed r4 is 7888605
# Last observed r4 is 16609849
# Last observed r4 is 4538029
# Last observed r4 is 14647757
# Last observed r4 is 10394870
# Last observed r4 is 15586564
# Last observed r4 is 12359769
# Last observed r4 is 11589059
# Last observed r4 is 2139442
# Last observed r4 is 5147471
# Last observed r4 is 1669926
# Last observed r4 is 10205625
# Last observed r4 is 3776134
# Last observed r4 is 1500548
# Last observed r4 is 13876727
# Last observed r4 is 16733420
# Last observed r4 is 6094302
# Last observed r4 is 1038271
# Last observed r4 is 1725346
# Last observed r4 is 3672027
# Last observed r4 is 4878836
# Last observed r4 is 4665391
# Last observed r4 is 11333035
# Last observed r4 is 15218966
# Last observed r4 is 7235527
# Last observed r4 is 2133354
# Last observed r4 is 1997855
# Last observed r4 is 5750447
# Last observed r4 is 16560249
# Last observed r4 is 13433915
# Last observed r4 is 9448189
# Last observed r4 is 13668621
# Last observed r4 is 7042668
# Last observed r4 is 679700
# Last observed r4 is 9821133
# Last observed r4 is 4532498
# Last observed r4 is 3531359
# Last observed r4 is 11929687
# Last observed r4 is 2067595
# Last observed r4 is 14998851
# Last observed r4 is 10935094
# Last observed r4 is 7949731
# Last observed r4 is 9132322
# Last observed r4 is 4885889
# Last observed r4 is 12092194
# Last observed r4 is 15286549
# Last observed r4 is 2728252
# Last observed r4 is 2565889
# Last observed r4 is 1380576
# Last observed r4 is 14066952
# Last observed r4 is 3762115
# Last observed r4 is 14077836
# Last observed r4 is 2847977
# Last observed r4 is 7967593
# Last observed r4 is 8531178
# Last observed r4 is 1452156
# Last observed r4 is 3332298
# Last observed r4 is 4980984
# Last observed r4 is 225448
# Last observed r4 is 11886266
# Last observed r4 is 9414644
# Last observed r4 is 1844129
# Last observed r4 is 11840430
# Last observed r4 is 5121461
# Last observed r4 is 16264834
# Last observed r4 is 4412296
# Last observed r4 is 14802981
# Last observed r4 is 10030075
# Last observed r4 is 10915672
# Last observed r4 is 16630205
# Last observed r4 is 7319696
# Last observed r4 is 11402838
# Last observed r4 is 10698704
# Last observed r4 is 12593449
# Last observed r4 is 2252200
# Last observed r4 is 13457503
# Last observed r4 is 14510117
# Last observed r4 is 5488535
# Last observed r4 is 6030782
# Last observed r4 is 3254823
# Last observed r4 is 6371339
# Last observed r4 is 14167205
# Last observed r4 is 1916943
# Last observed r4 is 6771533
# Last observed r4 is 15158288
# Last observed r4 is 5729978
# Last observed r4 is 11619898
# Last observed r4 is 10308920
# Last observed r4 is 10974589
# Last observed r4 is 12669682
# Last observed r4 is 9161332
# Last observed r4 is 3298240
# Last observed r4 is 14810013
# Last observed r4 is 11050086
# Last observed r4 is 3929218
# Last observed r4 is 9855284
# Last observed r4 is 7221795
# Last observed r4 is 4904945
# Last observed r4 is 4829420
# Last observed r4 is 4650568
# Last observed r4 is 3706076
# Last observed r4 is 8960100
# Last observed r4 is 11688632
# Last observed r4 is 2351508
# Last observed r4 is 13470023
# Last observed r4 is 12666310
# Last observed r4 is 12437707
# Last observed r4 is 5993833
# Last observed r4 is 1290418
# Last observed r4 is 16170728
# Last observed r4 is 11706836
# Last observed r4 is 9747447
# Last observed r4 is 1111952
# Last observed r4 is 3684955
# Last observed r4 is 14996303
# Last observed r4 is 7410656
# Last observed r4 is 12267431
# Last observed r4 is 9492054
# Last observed r4 is 13019956
# Last observed r4 is 999341
# Last observed r4 is 8468468
# Last observed r4 is 9232087
# Last observed r4 is 16105763
# Last observed r4 is 8067914
# Last observed r4 is 11287291
# Last observed r4 is 6499243
# Last observed r4 is 15450102
# Last observed r4 is 12754963
# Last observed r4 is 2274651
# Last observed r4 is 9962240
# Last observed r4 is 2257967
# Last observed r4 is 15299523
# Last observed r4 is 11004360
# Last observed r4 is 989975
# Last observed r4 is 4701518
# Last observed r4 is 4004765
# Last observed r4 is 86522
# Last observed r4 is 1677843
# Last observed r4 is 6796279
# Last observed r4 is 2269326
# Last observed r4 is 14134876
# Last observed r4 is 6933376
# Last observed r4 is 2259495
# Last observed r4 is 13803905
# Last observed r4 is 2194030
# Last observed r4 is 2734512
# Last observed r4 is 10173941
# Last observed r4 is 12316766
# Last observed r4 is 528420
# Last observed r4 is 3720976
# Last observed r4 is 7456483
# Last observed r4 is 13872123
# Last observed r4 is 14849334
# Last observed r4 is 10806305
# Last observed r4 is 11096191
# Last observed r4 is 9742769
# Last observed r4 is 9209820
# Last observed r4 is 10822115
# Last observed r4 is 13513850
# Last observed r4 is 148920
# Last observed r4 is 12234455
# Last observed r4 is 10715053
# Last observed r4 is 1488912
# Last observed r4 is 10972630
# Last observed r4 is 11654661
# Last observed r4 is 6103633
# Last observed r4 is 9972165
# Last observed r4 is 15755140
# Last observed r4 is 6134791
# Last observed r4 is 2213361
# Last observed r4 is 15680604
# Last observed r4 is 1101038
# Last observed r4 is 12102594
# Last observed r4 is 11755997
# Last observed r4 is 12569762
# Last observed r4 is 16136664
# Last observed r4 is 2847367
# Last observed r4 is 15545905
# Last observed r4 is 7184905
# Last observed r4 is 4957597
# Last observed r4 is 8445326
# Last observed r4 is 11459003
# Last observed r4 is 5753512
# Last observed r4 is 16435936
# Last observed r4 is 11527572
# Last observed r4 is 12212911
# Last observed r4 is 11777
# Last observed r4 is 14085645
# Last observed r4 is 15367203
# Last observed r4 is 3690815
# Last observed r4 is 12908762
# Last observed r4 is 2944078
# Last observed r4 is 13334198
# Last observed r4 is 13801266
# Last observed r4 is 3236247
# Last observed r4 is 15259034
# Last observed r4 is 9546575
# Last observed r4 is 6041564
# Last observed r4 is 3403323
# Last observed r4 is 2435713
# Last observed r4 is 606133
# Last observed r4 is 10621450
# Last observed r4 is 345714
# Last observed r4 is 4224436
# Last observed r4 is 6690853
# Last observed r4 is 6045301
# Last observed r4 is 15167917
# Last observed r4 is 9106014
# Last observed r4 is 8900998
# Last observed r4 is 7200505
# Last observed r4 is 8050377
# Last observed r4 is 14648651
# Last observed r4 is 8832436
# Last observed r4 is 2970935
# Last observed r4 is 15863842
# Last observed r4 is 1727032
# Last observed r4 is 1892492
# Last observed r4 is 13146996
# Last observed r4 is 13118387
# Last observed r4 is 7942960
# Last observed r4 is 7084303
# Last observed r4 is 13589134
# Last observed r4 is 7594922
# Last observed r4 is 3731275
# Last observed r4 is 5307116
# Last observed r4 is 12569370
# Last observed r4 is 8989447
# Last observed r4 is 16044204
# Last observed r4 is 12397708
# Last observed r4 is 8885312
# Last observed r4 is 10549810
# Last observed r4 is 8923196
# Last observed r4 is 7234992
# Last observed r4 is 48259
# Last observed r4 is 2118353
# Last observed r4 is 4882657
# Last observed r4 is 9633501
# Last observed r4 is 1657527
# Last observed r4 is 261971
# Last observed r4 is 12696706
# Last observed r4 is 14452414
# Last observed r4 is 9158368
# Last observed r4 is 2041368
# Last observed r4 is 10800708
# Last observed r4 is 12792818
# Last observed r4 is 6650083
# Last observed r4 is 16172697
# Last observed r4 is 15907327
# Last observed r4 is 15096320
# Last observed r4 is 14274472
# Last observed r4 is 11899091
# Last observed r4 is 3781681
# Last observed r4 is 653787
# Last observed r4 is 5030086
# Last observed r4 is 1209138
# Last observed r4 is 1044307
# Last observed r4 is 5087734
# Last observed r4 is 13856347
# Last observed r4 is 6306625
# Last observed r4 is 6729298
# Last observed r4 is 13144434
# Last observed r4 is 5134291
# Last observed r4 is 12224606
# Last observed r4 is 4650236
# Last observed r4 is 15954374
# Last observed r4 is 1083261
# Last observed r4 is 5943106
# Last observed r4 is 4636151
# Last observed r4 is 7507560
# Last observed r4 is 4143736
# Last observed r4 is 7852344
# Last observed r4 is 14853887
# Last observed r4 is 13504405
# Last observed r4 is 5053884
# Last observed r4 is 5774377
# Last observed r4 is 12691147
# Last observed r4 is 11476611
# Last observed r4 is 8231773
# Last observed r4 is 783482
# Last observed r4 is 4143756
# Last observed r4 is 14223284
# Last observed r4 is 2999343
# Last observed r4 is 7625665
# Last observed r4 is 15289166
# Last observed r4 is 11455217
# Last observed r4 is 11934547
# Last observed r4 is 1330938
# Last observed r4 is 10858052
# Last observed r4 is 12770514
# Last observed r4 is 6535844
# Last observed r4 is 7552776
# Last observed r4 is 12829761
# Last observed r4 is 6467145
# Last observed r4 is 10013915
# Last observed r4 is 15012465
# Last observed r4 is 3950957
# Last observed r4 is 15237032
# Last observed r4 is 4509107
# Last observed r4 is 10891542
# Last observed r4 is 7074921
# Last observed r4 is 5054761
# Last observed r4 is 15573860
# Last observed r4 is 6205271
# Last observed r4 is 11589234
# Last observed r4 is 7270824
# Last observed r4 is 16471831
# Last observed r4 is 14004046
# Last observed r4 is 16498393
# Last observed r4 is 7192227
# Last observed r4 is 14187463
# Last observed r4 is 7035436
# Last observed r4 is 3341848
# Last observed r4 is 16463544
# Last observed r4 is 779688
# Last observed r4 is 7776415
# Last observed r4 is 4119747
# Last observed r4 is 9836187
# Last observed r4 is 1706837
# Last observed r4 is 65244
# Last observed r4 is 8494942
# Last observed r4 is 7659869
# Last observed r4 is 1353656
# Last observed r4 is 8246063
# Last observed r4 is 7140872
# Last observed r4 is 2600446
# Last observed r4 is 16006077
# Last observed r4 is 5650530
# Last observed r4 is 7667372
# Last observed r4 is 848970
# Last observed r4 is 5762514
# Last observed r4 is 5197769
# Last observed r4 is 13227864
# Last observed r4 is 14726651
# Last observed r4 is 6341706
# Last observed r4 is 2875966
# Last observed r4 is 758646
# Last observed r4 is 5423399
# Last observed r4 is 15443680
# Last observed r4 is 4156640
# Last observed r4 is 10607378
# Last observed r4 is 12863861
# Last observed r4 is 9970456
# Last observed r4 is 9925399
# Last observed r4 is 1142206
# Last observed r4 is 10901899
# Last observed r4 is 6624064
# Last observed r4 is 10840771
# Last observed r4 is 13332699
# Last observed r4 is 7757531
# Last observed r4 is 15840957
# Last observed r4 is 1802649
# Last observed r4 is 14468654
# Last observed r4 is 13663856
# Last observed r4 is 4486858
# Last observed r4 is 11341740
# Last observed r4 is 10139899
# Last observed r4 is 10643763
# Last observed r4 is 3505308
# Last observed r4 is 13464168
# Last observed r4 is 16346586
# Last observed r4 is 1555351
# Last observed r4 is 12559814
# Last observed r4 is 12372821
# Last observed r4 is 10874706
# Last observed r4 is 14654037
# Last observed r4 is 7313951
# Last observed r4 is 16286157
# Last observed r4 is 12108244
# Last observed r4 is 10165145
# Last observed r4 is 5006840
# Last observed r4 is 3965861
# Last observed r4 is 15290298
# Last observed r4 is 1820889
# Last observed r4 is 16555069
# Last observed r4 is 13181523
# Last observed r4 is 949135
# Last observed r4 is 9439638
# Last observed r4 is 233935
# Last observed r4 is 4933944
# Last observed r4 is 16053843
# Last observed r4 is 1899303
# Last observed r4 is 10876984
# Last observed r4 is 16339560
# Last observed r4 is 2446622
# Last observed r4 is 7372975
# Last observed r4 is 12987529
# Last observed r4 is 8588661
# Last observed r4 is 11870758
# Last observed r4 is 2073756
# Last observed r4 is 7847966
# Last observed r4 is 792648
# Last observed r4 is 11263536
# Last observed r4 is 15217032
# Last observed r4 is 14184181
# Last observed r4 is 5426609
# Last observed r4 is 11177034
# Last observed r4 is 3519156
# Last observed r4 is 13806902
# Last observed r4 is 13962953
# Last observed r4 is 7857249
# Last observed r4 is 11674629
# Last observed r4 is 2965637
# Last observed r4 is 11860031
# Last observed r4 is 2846557
# Last observed r4 is 10029160
# Last observed r4 is 5505924
# Last observed r4 is 6270607
# Last observed r4 is 15271393
# Last observed r4 is 6852612
# Last observed r4 is 16720208
# Last observed r4 is 6172783
# Last observed r4 is 16524403
# Last observed r4 is 9327901
# Last observed r4 is 14039722
# Last observed r4 is 241910
# Last observed r4 is 3223108
# Last observed r4 is 5037014
# Last observed r4 is 2654693
# Last observed r4 is 6046380
# Last observed r4 is 5427814
# Last observed r4 is 7736726
# Last observed r4 is 4814805
# Last observed r4 is 12488610
# Last observed r4 is 8229827
# Last observed r4 is 3909572
# Last observed r4 is 14572789
# Last observed r4 is 2663729
# Last observed r4 is 5356116
# Last observed r4 is 14437266
# Last observed r4 is 15548409
# Last observed r4 is 13753186
# Last observed r4 is 7956341
# Last observed r4 is 10225922
# Last observed r4 is 4211415
# Last observed r4 is 502947
# Last observed r4 is 4307491
# Last observed r4 is 14551295
# Last observed r4 is 7887803
# Last observed r4 is 13641480
# Last observed r4 is 14813235
# Last observed r4 is 10276675
# Last observed r4 is 9326336
# Last observed r4 is 3749101
# Last observed r4 is 10119759
# Last observed r4 is 9276689
# Last observed r4 is 14318696
# Last observed r4 is 7838958
# Last observed r4 is 10402228
# Last observed r4 is 2446995
# Last observed r4 is 8467799
# Last observed r4 is 14793342
# Last observed r4 is 3751264
# Last observed r4 is 8726809
# Last observed r4 is 9978724
# Last observed r4 is 602843
# Last observed r4 is 6464247
# Last observed r4 is 13003929
# Last observed r4 is 13730021
# Last observed r4 is 2960939
# Last observed r4 is 13586959
# Last observed r4 is 4882613
# Last observed r4 is 12394649
# Last observed r4 is 10920907
# Last observed r4 is 848250
# Last observed r4 is 12137783
# Last observed r4 is 8290182
# Last observed r4 is 3470431
# Last observed r4 is 15087961
# Last observed r4 is 11669162
# Last observed r4 is 12518942
# Last observed r4 is 6456310
# Last observed r4 is 10042335
# Last observed r4 is 10418420
# Last observed r4 is 8722138
# Last observed r4 is 3811900
# Last observed r4 is 13630600
# Last observed r4 is 553674
# Last observed r4 is 1093556
# Last observed r4 is 2519551
# Last observed r4 is 5797044
# Last observed r4 is 10893172
# Last observed r4 is 4516665
# Last observed r4 is 10847030
# Last observed r4 is 3562293
# Last observed r4 is 161280
# Last observed r4 is 9754776
# Last observed r4 is 12288952
# Last observed r4 is 12868749
# Last observed r4 is 1375899
# Last observed r4 is 5884583
# Last observed r4 is 16249187
# Last observed r4 is 3454352
# Last observed r4 is 11254197
# Last observed r4 is 3556330
# Last observed r4 is 3275607
# Last observed r4 is 10708004
# Last observed r4 is 11830818
# Last observed r4 is 7160724
# Last observed r4 is 12993543
# Last observed r4 is 4943015
# Last observed r4 is 10018203
# Last observed r4 is 404474
# Last observed r4 is 998175
# Last observed r4 is 7272198
# Last observed r4 is 16251623
# Last observed r4 is 5138653
# Last observed r4 is 4411877
# Last observed r4 is 16114906
# Last observed r4 is 8190442
# Last observed r4 is 675359
# Last observed r4 is 7546133
# Last observed r4 is 1224110
# Last observed r4 is 5981553
# Last observed r4 is 12193946
# Last observed r4 is 2707896
# Last observed r4 is 66917
# Last observed r4 is 2395864
# Last observed r4 is 1126446
# Last observed r4 is 7455942
# Last observed r4 is 9875746
# Last observed r4 is 9932317
# Last observed r4 is 16179507
# Last observed r4 is 13318768
# Last observed r4 is 14529828
# Last observed r4 is 4699369
# Last observed r4 is 9857373
# Last observed r4 is 16093494
# Last observed r4 is 5698243
# Last observed r4 is 4093065
# Last observed r4 is 12259493
# Last observed r4 is 6211913
# Last observed r4 is 6099122
# Last observed r4 is 4158518
# Last observed r4 is 2597308
# Last observed r4 is 9653675
# Last observed r4 is 13394072
# Last observed r4 is 11701352
# Last observed r4 is 13602758
# Last observed r4 is 3974687
# Last observed r4 is 15096723
# Last observed r4 is 8148490
# Last observed r4 is 4180404
# Last observed r4 is 4520451
# Last observed r4 is 4665995
# Last observed r4 is 1843441
# Last observed r4 is 11631987
# Last observed r4 is 5954474
# Last observed r4 is 6338427
# Last observed r4 is 2222780
# Last observed r4 is 2493418
# Last observed r4 is 14765103
# Last observed r4 is 15209541
# Last observed r4 is 1734215
# Last observed r4 is 398757
# Last observed r4 is 14800810
# Last observed r4 is 8874649
# Last observed r4 is 14753971
# Last observed r4 is 4798277
# Last observed r4 is 127666
# Last observed r4 is 9787668
# Last observed r4 is 1085221
# Last observed r4 is 7276674
# Last observed r4 is 11020388
# Last observed r4 is 5308424
# Last observed r4 is 7923844
# Last observed r4 is 12472600
# Last observed r4 is 9315895
# Last observed r4 is 11279137
# Last observed r4 is 1521814
# Last observed r4 is 3237064
# Last observed r4 is 6228392
# Last observed r4 is 2672831
# Last observed r4 is 9195433
# Last observed r4 is 7120098
# Last observed r4 is 1731946
# Last observed r4 is 1580157
# Last observed r4 is 1677127
# Last observed r4 is 14445736
# Last observed r4 is 3180788
# Last observed r4 is 9783792
# Last observed r4 is 12434153
# Last observed r4 is 1908997
# Last observed r4 is 943016
# Last observed r4 is 13192281
# Last observed r4 is 10229723
# Last observed r4 is 3091280
# Last observed r4 is 16590009
# Last observed r4 is 14848975
# Last observed r4 is 14453834
# Last observed r4 is 6814106
# Last observed r4 is 7296253
# Last observed r4 is 2020145
# Last observed r4 is 1583460
# Last observed r4 is 9975441
# Last observed r4 is 15452685
# Last observed r4 is 10368635
# Last observed r4 is 8840045
# Last observed r4 is 2395104
# Last observed r4 is 11537051
# Last observed r4 is 1314695
# Last observed r4 is 5114228
# Last observed r4 is 1831219
# Last observed r4 is 7220748
# Last observed r4 is 8061336
# Last observed r4 is 3609979
# Last observed r4 is 4584988
# Last observed r4 is 6335426
# Last observed r4 is 5956885
# Last observed r4 is 16553574
# Last observed r4 is 8411976
# Last observed r4 is 11090199
# Last observed r4 is 3336538
# Last observed r4 is 8637169
# Last observed r4 is 9034991
# Last observed r4 is 11951565
# Last observed r4 is 1442362
# Last observed r4 is 14787566
# Last observed r4 is 15819537
# Last observed r4 is 13539290
# Last observed r4 is 6156899
# Last observed r4 is 7462379
# Last observed r4 is 6475058
# Last observed r4 is 5330381
# Last observed r4 is 15686608
# Last observed r4 is 11329833
# Last observed r4 is 5256772
# Last observed r4 is 2957054
# Last observed r4 is 5291752
# Last observed r4 is 767602
# Last observed r4 is 13086502
# Last observed r4 is 2833927
# Last observed r4 is 10387229
# Last observed r4 is 5686196
# Last observed r4 is 5049269
# Last observed r4 is 386274
# Last observed r4 is 11700274
# Last observed r4 is 6884192
# Last observed r4 is 8709383
# Last observed r4 is 14861674
# Last observed r4 is 2238381
# Last observed r4 is 5575416
# Last observed r4 is 3910914
# Last observed r4 is 4159077
# Last observed r4 is 12327531
# Last observed r4 is 11992203
# Last observed r4 is 16704955
# Last observed r4 is 13130948
# Last observed r4 is 2382364
# Last observed r4 is 10409382
# Last observed r4 is 8492613
# Last observed r4 is 6505665
# Last observed r4 is 7271209
# Last observed r4 is 4329308
# Last observed r4 is 11225277
# Last observed r4 is 258777
# Last observed r4 is 5565583
# Last observed r4 is 3121281
# Last observed r4 is 10784553
# Last observed r4 is 1526698
# Last observed r4 is 10145535
# Last observed r4 is 4593253
# Last observed r4 is 12787811
# Last observed r4 is 10891979
# Last observed r4 is 11779537
# Last observed r4 is 2519866
# Last observed r4 is 4910663
# Last observed r4 is 7839853
# Last observed r4 is 9158341
# Last observed r4 is 10217815
# Last observed r4 is 14535024
# Last observed r4 is 10048513
# Last observed r4 is 8400139
# Last observed r4 is 11549714
# Last observed r4 is 11185982
# Last observed r4 is 8633883
# Last observed r4 is 5869281
# Last observed r4 is 7420117
# Last observed r4 is 12459219
# Last observed r4 is 6456971
# Last observed r4 is 1650009
# Last observed r4 is 12765668
# Last observed r4 is 11732159
# Last observed r4 is 11861427
# Last observed r4 is 9917078
# Last observed r4 is 10641682
# Last observed r4 is 13959201
# Last observed r4 is 7808971
# Last observed r4 is 3890126
# Last observed r4 is 15608135
# Last observed r4 is 14839964
# Last observed r4 is 6047862
# Last observed r4 is 6056250
# Last observed r4 is 1122207
# Last observed r4 is 4118304
# Last observed r4 is 4571173
# Last observed r4 is 16504743
# Last observed r4 is 9632382
# Last observed r4 is 15432966
# Last observed r4 is 8609425
# Last observed r4 is 9836483
# Last observed r4 is 11827974
# Last observed r4 is 10292365
# Last observed r4 is 7072787
# Last observed r4 is 15402879
# Last observed r4 is 4079750
# Last observed r4 is 13364760
# Last observed r4 is 1303216
# Last observed r4 is 1936996
# Last observed r4 is 13979450
# Last observed r4 is 10060541
# Last observed r4 is 1674237
# Last observed r4 is 3206910
# Last observed r4 is 14088932
# Last observed r4 is 2074244
# Last observed r4 is 11738568
# Last observed r4 is 16318639
# Last observed r4 is 5083361
# Last observed r4 is 1387843
# Last observed r4 is 5494038
# Last observed r4 is 7945169
# Last observed r4 is 3849994
# Last observed r4 is 9865727
# Last observed r4 is 611548
# Last observed r4 is 1563612
# Last observed r4 is 1007429
# Last observed r4 is 8916316
# Last observed r4 is 4302477
# Last observed r4 is 68841
# Last observed r4 is 9321651
# Last observed r4 is 9899835
# Last observed r4 is 6248742
# Last observed r4 is 3260521
# Last observed r4 is 3293527
# Last observed r4 is 11758736
# Last observed r4 is 9545118
# Last observed r4 is 13376803
# Last observed r4 is 15803406
# Last observed r4 is 9918298
# Last observed r4 is 11979579
# Last observed r4 is 2197090
# Last observed r4 is 1017464
# Last observed r4 is 6839316
# Last observed r4 is 7100652
# Last observed r4 is 2767292
# Last observed r4 is 14039087
# ...
# Last observed r4 is 8045475
# Last observed r4 is 2006334
# Last observed r4 is 13026965
# Last observed r4 is 11469987
# Last observed r4 is 2678515
# Last observed r4 is 1657963
# Last observed r4 is 4365345
# Last observed r4 is 8782209
# Last observed r4 is 13851402
# Last observed r4 is 13521219
# Last observed r4 is 7290584
# Last observed r4 is 14335820
# Last observed r4 is 7879237
# Last observed r4 is 12205805
# Last observed r4 is 9256415
# Last observed r4 is 4386146
# Last observed r4 is 1756957
# Last observed r4 is 5431896
# Last observed r4 is 11676828
# Last observed r4 is 13323074
# Last observed r4 is 5655683
# Last observed r4 is 16096211
# Last observed r4 is 12725476
# Last observed r4 is 3758410
# Last observed r4 is 12224051
# Last observed r4 is 12971417
# Last observed r4 is 11066696
# Last observed r4 is 8573889
# Last observed r4 is 3712480
# Last observed r4 is 11824577
# Last observed r4 is 5887760
# Last observed r4 is 1187795
# Last observed r4 is 4037330
# Last observed r4 is 2902256
# Last observed r4 is 8201400
# Last observed r4 is 6095356
# Last observed r4 is 16710493
# Last observed r4 is 9417264
# Last observed r4 is 11244040
# Last observed r4 is 325028
# Last observed r4 is 14506593
# Last observed r4 is 10960109
# Last observed r4 is 13179921
# Last observed r4 is 12426707
# Last observed r4 is 3793646
# Last observed r4 is 7413856
# Last observed r4 is 4532620
# Last observed r4 is 8839661
# Last observed r4 is 14856174
# Last observed r4 is 1279635
# Last observed r4 is 15703681
# Last observed r4 is 11901431
# Last observed r4 is 8439902
# Last observed r4 is 872702
# Last observed r4 is 6363562
# Last observed r4 is 11841483
# Last observed r4 is 3876352
# Last observed r4 is 5000752
# Last observed r4 is 533550
# Last observed r4 is 4823234
# Last observed r4 is 3837778
# Last observed r4 is 7601831
# Last observed r4 is 15901653
# Last observed r4 is 9042044
# Last observed r4 is 2601152
# Last observed r4 is 5171150
# Last observed r4 is 2343631
# Last observed r4 is 12844033
# Last observed r4 is 7090689
# Last observed r4 is 10719765
# Last observed r4 is 3938947
# Last observed r4 is 11202259
# Last observed r4 is 8431089
# Last observed r4 is 5207388
# Last observed r4 is 13135735
# Last observed r4 is 11946208
# Last observed r4 is 12198710
# Last observed r4 is 4945159
# Last observed r4 is 2572860
# Last observed r4 is 16523652
# Last observed r4 is 5828213
# Last observed r4 is 6638385
# Last observed r4 is 10295902
# Last observed r4 is 5742324
# Last observed r4 is 4963256
# Last observed r4 is 9721397
# Last observed r4 is 2682285
# Last observed r4 is 7157392
# Last observed r4 is 12234582
# Last observed r4 is 556179
# Last observed r4 is 7697689
# Last observed r4 is 11074464
# Last observed r4 is 8315383
# Last observed r4 is 737236
# Last observed r4 is 3850989
# Last observed r4 is 7204803
# Last observed r4 is 13405072
# Last observed r4 is 13901539
# Last observed r4 is 7762015
# Last observed r4 is 13053835
# Last observed r4 is 1363526
# Last observed r4 is 3940456
# Last observed r4 is 3654248
# Last observed r4 is 14906104
# Last observed r4 is 13335484
# Last observed r4 is 2608833
# Last observed r4 is 10753487
# Last observed r4 is 5037394
# Last observed r4 is 5696651
# Last observed r4 is 1978891
# Last observed r4 is 8765113
# Last observed r4 is 5999857
# Last observed r4 is 1112937
# Last observed r4 is 14333082
# Last observed r4 is 11222428
# Last observed r4 is 1797683
# Last observed r4 is 14993761
# Last observed r4 is 5797500
# Last observed r4 is 4590270
# Last observed r4 is 5478546
# Last observed r4 is 5983728
# Last observed r4 is 14906255
# Last observed r4 is 10821738
# Last observed r4 is 11144838
# Last observed r4 is 524058
# Last observed r4 is 11580339
# Last observed r4 is 2261872
# Last observed r4 is 13471149
# Last observed r4 is 1120700
# Last observed r4 is 12303409
# Last observed r4 is 5031929
# Last observed r4 is 15887050
# Last observed r4 is 3925434
# Last observed r4 is 16673413
# Last observed r4 is 16290911
# Last observed r4 is 11160037
# Last observed r4 is 10379914
# Last observed r4 is 15746070
# Last observed r4 is 12488978
# Last observed r4 is 7449221
# Last observed r4 is 6977861
# Last observed r4 is 13948570
# Last observed r4 is 5607852
# Last observed r4 is 15965733
# Last observed r4 is 16413135
# Last observed r4 is 4477376
# Last observed r4 is 4460465
# Last observed r4 is 4879138
# Last observed r4 is 16415115
# Last observed r4 is 12181884
# Last observed r4 is 15709745
# Last observed r4 is 7405919
# Last observed r4 is 1571026
# Last observed r4 is 5706492
# Last observed r4 is 5316900
# Last observed r4 is 14244721
# Last observed r4 is 13172522
# Last observed r4 is 12684281
# Last observed r4 is 13003754
# Last observed r4 is 8598639
# Last observed r4 is 8413795
# Last observed r4 is 1345767
# Last observed r4 is 3797509
# Last observed r4 is 8701029
# Last observed r4 is 13849099
# Last observed r4 is 3872021
# Last observed r4 is 5911222
# Last observed r4 is 81726
# Last observed r4 is 5741597
# Last observed r4 is 8826001
# Last observed r4 is 7008717
# Last observed r4 is 11217258
# Last observed r4 is 4730761
# Last observed r4 is 9200374
# Last observed r4 is 15408532
# Last observed r4 is 3444539
# Last observed r4 is 16657072
# Last observed r4 is 13166608
# Last observed r4 is 14347500
# Last observed r4 is 8022186
# Last observed r4 is 7842752
# Last observed r4 is 6769569
# Last observed r4 is 12550532
# Last observed r4 is 1809387
# Last observed r4 is 6004622
# Last observed r4 is 3668747
# Last observed r4 is 3671042
# Last observed r4 is 10725230
# Last observed r4 is 10808459
# Last observed r4 is 7119013
# Last observed r4 is 9560767
# Last observed r4 is 15018475
# Last observed r4 is 16091034
# Last observed r4 is 13428725
# Last observed r4 is 6293022
# Last observed r4 is 261804
# Last observed r4 is 10113700
# Last observed r4 is 15364936
# Last observed r4 is 5509309
# Last observed r4 is 7135343
# Last observed r4 is 9181053
# Last observed r4 is 5647910
# Last observed r4 is 14761982
# Last observed r4 is 14555133
# Last observed r4 is 1493996
# Last observed r4 is 14481637
# Last observed r4 is 8029671
# Last observed r4 is 1604220
# Last observed r4 is 6666978
# Last observed r4 is 10657272
# Last observed r4 is 13866511
# Last observed r4 is 11485061
# Last observed r4 is 6270428
# Last observed r4 is 8865823
# Last observed r4 is 14664851
# Last observed r4 is 878739
# Last observed r4 is 10044497
# Last observed r4 is 8706923
# Last observed r4 is 5814940
# Last observed r4 is 4345410
# Last observed r4 is 5608406
# Last observed r4 is 7326005
# Last observed r4 is 782566
# Last observed r4 is 15475372
# Last observed r4 is 14894966
# Last observed r4 is 730243
# Last observed r4 is 15254311
# Last observed r4 is 3309828
# Last observed r4 is 2141159
# Last observed r4 is 13525588
# Last observed r4 is 1707684
# Last observed r4 is 591012
# Last observed r4 is 8835044
# Last observed r4 is 8830977
# Last observed r4 is 9386385
# Last observed r4 is 6931466
# Last observed r4 is 16570582
# Last observed r4 is 5337930
# Last observed r4 is 12775173
# Last observed r4 is 8880104
# Last observed r4 is 1660797
# Last observed r4 is 14825450
# Last observed r4 is 12504719
# Last observed r4 is 4842785
# Last observed r4 is 2412740
# Last observed r4 is 6335844
# Last observed r4 is 4326413
# Last observed r4 is 14888237
# Last observed r4 is 12061198
# Last observed r4 is 7258408
# Last observed r4 is 830183
# Last observed r4 is 14828351
# Last observed r4 is 10470346
# Last observed r4 is 24815
# Last observed r4 is 9194329
# Last observed r4 is 8896526
# Last observed r4 is 13527496
# Last observed r4 is 3536719
# Last observed r4 is 2128980
# Last observed r4 is 5988020
# Last observed r4 is 1572452
# Last observed r4 is 5273512
# Last observed r4 is 15458403
# Last observed r4 is 13661763
# Last observed r4 is 11118187
# Last observed r4 is 12868955
# Last observed r4 is 16382238
# Last observed r4 is 10972111
# Last observed r4 is 14666318
# Last observed r4 is 13506186
# Last observed r4 is 16759098
# Last observed r4 is 3464997
# Last observed r4 is 1316190
# Last observed r4 is 9883775
# Last observed r4 is 8645803
# Last observed r4 is 15071951
# Last observed r4 is 13084559
# Last observed r4 is 6915658
# Last observed r4 is 14894280
# Last observed r4 is 1158894
# Last observed r4 is 6838804
# Last observed r4 is 12342138
# Last observed r4 is 1605785
# Last observed r4 is 180383
# Last observed r4 is 686495
# Last observed r4 is 2737064
# Last observed r4 is 14972567
# Last observed r4 is 5639683
# Last observed r4 is 3590533
# Last observed r4 is 5798766
# Last observed r4 is 3804113
# Last observed r4 is 8119408
# Last observed r4 is 16716430
# Last observed r4 is 14902194
# Last observed r4 is 13571123
# Last observed r4 is 11064211
# Last observed r4 is 8340696
# Last observed r4 is 16442962
# Last observed r4 is 10353606
# Last observed r4 is 2852165
# Last observed r4 is 11836550
# Last observed r4 is 14913510
# Last observed r4 is 15486171
# Last observed r4 is 3681549
# Last observed r4 is 7442080
# Last observed r4 is 5073354
# Last observed r4 is 12384159
# Last observed r4 is 3020572
# Last observed r4 is 2108777
# Last observed r4 is 1612396
# Last observed r4 is 1592530
# Last observed r4 is 3621254
# Last observed r4 is 10216825
# Last observed r4 is 2294162
# Last observed r4 is 12676801
# Last observed r4 is 4057805
# Last observed r4 is 9753889
# Last observed r4 is 15798520
# Last observed r4 is 2655428
# Last observed r4 is 4449316
# Last observed r4 is 5593730
# Last observed r4 is 12509896
# Last observed r4 is 4139536
# Last observed r4 is 16655344
# Last observed r4 is 1567169
# Last observed r4 is 6047906
# Last observed r4 is 3295102
# Last observed r4 is 8457611
# Last observed r4 is 1969778
# Last observed r4 is 1704474
# Last observed r4 is 4857658
# Last observed r4 is 9321631
# Last observed r4 is 3528895
# Last observed r4 is 1608765
# Last observed r4 is 6534007
# Last observed r4 is 11563362
# Last observed r4 is 15210875
# Last observed r4 is 5832038
# Last observed r4 is 12880683
# Last observed r4 is 14755532
# Last observed r4 is 13814710
# Last observed r4 is 9669111
# Last observed r4 is 14576792
# Last observed r4 is 14993050
# Last observed r4 is 15039692
# Last observed r4 is 6798216
# Last observed r4 is 13053529
# Last observed r4 is 4834135
# Last observed r4 is 8056244
# Last observed r4 is 14790939
# Last observed r4 is 12579014
# Last observed r4 is 366472
# Last observed r4 is 278879
# Last observed r4 is 11275758
# Last observed r4 is 2851055
# Last observed r4 is 11984391
# Last observed r4 is 2947393
# Last observed r4 is 8677860
# Last observed r4 is 7579509
# Last observed r4 is 9875136
# Last observed r4 is 1016108
# Last observed r4 is 12510675
# Last observed r4 is 16558540
# Last observed r4 is 7886869
# Last observed r4 is 2179339
# Last observed r4 is 3140198
# Last observed r4 is 9575394
# Last observed r4 is 10956363
# Last observed r4 is 15042925
# Last observed r4 is 9575456
# Last observed r4 is 13646366
# Last observed r4 is 5581584
# Last observed r4 is 15484379
# Last observed r4 is 5249534
# Last observed r4 is 3990615
# Last observed r4 is 4667017
# Last observed r4 is 7500591
# Last observed r4 is 6414970
# Last observed r4 is 6652796
# Last observed r4 is 4865831
# Last observed r4 is 3291542
# Last observed r4 is 2461493
# Last observed r4 is 13691406
# Last observed r4 is 8996112
# Last observed r4 is 1103457
# Last observed r4 is 8088901
# Last observed r4 is 12897438
# Last observed r4 is 15257870
# Last observed r4 is 8987399
# Last observed r4 is 3455716
# Last observed r4 is 8131214
# Last observed r4 is 6335324
# Last observed r4 is 7019523
# Last observed r4 is 1772543
# Last observed r4 is 3886586
# Last observed r4 is 15982957
# Last observed r4 is 14753682
# Last observed r4 is 13684185
# Last observed r4 is 15444972
# Last observed r4 is 11652705
# Last observed r4 is 6044253
# Last observed r4 is 1228545
# Last observed r4 is 4362844
# Last observed r4 is 3452264
# Last observed r4 is 2701045
# Last observed r4 is 6372265
# Last observed r4 is 6303754
# Last observed r4 is 1260170
# Last observed r4 is 10686634
# Last observed r4 is 6223072
# Last observed r4 is 8616634
# Last observed r4 is 16624970
# Last observed r4 is 6324435
# Last observed r4 is 6623621
# Last observed r4 is 4507568
# Last observed r4 is 8883143
# Last observed r4 is 10031478
# Last observed r4 is 3156111
# Last observed r4 is 11098065
# Last observed r4 is 741206
# Last observed r4 is 5668259
# Last observed r4 is 15313820
# Last observed r4 is 2814363
# Last observed r4 is 7849588
# Last observed r4 is 12463232
# Last observed r4 is 5194546
# Last observed r4 is 13353399
# Last observed r4 is 2113464
# Last observed r4 is 13158667
# Last observed r4 is 10111718
# Last observed r4 is 7023334
# Last observed r4 is 3837878
# Last observed r4 is 5902099
# Last observed r4 is 6330138
# Last observed r4 is 4855849
# Last observed r4 is 5474317
# Last observed r4 is 5548865
# Last observed r4 is 14405182
# Last observed r4 is 14440082
# Last observed r4 is 3497452
# Last observed r4 is 2750449
# Last observed r4 is 2611158
# Last observed r4 is 10633503
# Last observed r4 is 1300792
# Last observed r4 is 4075259
# Last observed r4 is 13922053
# Last observed r4 is 9977070
# Last observed r4 is 12575882
# Last observed r4 is 12702568
# Last observed r4 is 13001967
# Last observed r4 is 11759359
# Last observed r4 is 6107917
# Last observed r4 is 10867202
# Last observed r4 is 14840176
# Last observed r4 is 6188267
# Last observed r4 is 16220163
# Last observed r4 is 582343
# Last observed r4 is 8604587
# Last observed r4 is 803958
# Last observed r4 is 11267302
# Last observed r4 is 2947752
# Last observed r4 is 5313026
# Last observed r4 is 9170836
# Last observed r4 is 410333
# Last observed r4 is 15369303
# Last observed r4 is 16066531
# Last observed r4 is 3061312
# Last observed r4 is 16308732
# Last observed r4 is 14558377
# Last observed r4 is 7775253
# Last observed r4 is 4197665
# Last observed r4 is 14317908
# Last observed r4 is 9330247
# Last observed r4 is 3832009
# Last observed r4 is 5122717
# Last observed r4 is 12293207
# Last observed r4 is 4525923
# Last observed r4 is 13586904
# Last observed r4 is 4422439
# Last observed r4 is 13291930
# Last observed r4 is 1275361
# Last observed r4 is 1216898
# Last observed r4 is 15014641
# Last observed r4 is 6981813
# Last observed r4 is 10314689
# Last observed r4 is 13736398
# Last observed r4 is 14001863
# Last observed r4 is 11520403
# Last observed r4 is 1389088
# Last observed r4 is 14795610
# Last observed r4 is 2251317
# Last observed r4 is 1464043
# Last observed r4 is 2022917
# Last observed r4 is 9070867
# Last observed r4 is 8507444
# Last observed r4 is 82216
# Last observed r4 is 10269293
# Last observed r4 is 14820777
# Last observed r4 is 5418106
# Last observed r4 is 13032604
# Last observed r4 is 6375118
# Last observed r4 is 6039036
# Last observed r4 is 6249825
# Last observed r4 is 11571822
# Last observed r4 is 16435000
# Last observed r4 is 16205553
# Last observed r4 is 10295815
# Last observed r4 is 11583167
# Last observed r4 is 10810695
# Last observed r4 is 12202778
# Last observed r4 is 4425603
# Last observed r4 is 11149338
# Last observed r4 is 2833688
# Last observed r4 is 1646055
# Last observed r4 is 16045150
# Last observed r4 is 10622502
# Last observed r4 is 15559274
# Last observed r4 is 6503960
# Last observed r4 is 2715656
# Last observed r4 is 13754556
# Last observed r4 is 6744640
# Last observed r4 is 1160952
# Last observed r4 is 5835546
# Last observed r4 is 2133925
# Last observed r4 is 15550642
# Last observed r4 is 1104094
# Last observed r4 is 9111358
# Last observed r4 is 10602323
# Last observed r4 is 2098196
# Last observed r4 is 14877500
# Last observed r4 is 9470097
# Last observed r4 is 5539887
# Last observed r4 is 16511261
# Last observed r4 is 14974090
# Last observed r4 is 2551330
# Last observed r4 is 10458466
# Last observed r4 is 3564025
# Last observed r4 is 13317602
# Last observed r4 is 13616253
# Last observed r4 is 9593537
# Last observed r4 is 15698151
# Last observed r4 is 1386275
# Last observed r4 is 11024992
# Last observed r4 is 7192510
# Last observed r4 is 3390273
# Last observed r4 is 3787160
# Last observed r4 is 11982957
# Last observed r4 is 831997
# Last observed r4 is 3491184
# Last observed r4 is 9371237
# Last observed r4 is 13499939
# Last observed r4 is 13338791
# Last observed r4 is 12181335
# Last observed r4 is 9164992
# Last observed r4 is 7594626
# Last observed r4 is 10387354
# Last observed r4 is 11950139
# Last observed r4 is 1592647
# Last observed r4 is 7054126
# Last observed r4 is 13991295
# Last observed r4 is 12149402
# Last observed r4 is 5778980
# Last observed r4 is 14256686
# 14256686

# %%
#pmod.reddit_wrap()
#bots = pmod.get_bots()

# %%
#len(bots)

# %%
#pmod.count_for_point(bots,164366478, 104069375, 82992136, 536870912)
